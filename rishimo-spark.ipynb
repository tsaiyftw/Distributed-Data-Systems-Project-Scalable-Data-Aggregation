# %%
import pyspark
import dotenv

from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext

# %%
ss = SparkSession.builder.remote("sc://localhost").getOrCreate()

# %%
ss.read.format("mongodb").option("database", "SanFrancisco").option("collection", "sf_aggregations").load()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 ss.read.format("mongodb").option("database", "SanFrancisco").option("collection", "sf_aggregations").load()
#
# File /opt/homebrew/anaconda3/envs/msds697/lib/python3.8/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /opt/homebrew/anaconda3/envs/msds697/lib/python3.8/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
# ...
